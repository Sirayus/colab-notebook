# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirayus/colab-notebook/blob/main/2021MAY15_durian_th(canceled).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
from google.colab import files

# %%
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-a87526d4-2289-4125-b494-4020727c8031" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a87526d4-2289-4125-b494-4020727c8031">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ผลผลิตทุเรียนแยกตามจังหวัด ปี 2562.xlsx to ผลผลิตทุเรียนแยกตามจังหวัด ปี 2562.xlsx

# %%
df = pd.read_excel('/content/ผลผลิตทุเรียนแยกตามจังหวัด ปี 2562.xlsx', sheet_name=1)

# %%
df
# Out:
#            province  yield(ton)  ...  yield area(Rai)  yield per yield area (kg)
# 0          จันทบุรี      339292  ...           190728                    1778.93
# 1             ชุมพร      212764  ...           157837                    1348.00
# 2             ระยอง      108093  ...            64469                    1676.67
# 3              ตราด       48158  ...            26133                    1842.80
# 4      สุราษฎร์ธานี       47550  ...            39039                    1218.01
# 5     นครศรีธรรมราช       45632  ...            44958                    1014.99
# 6              ยะลา       39615  ...            48018                     825.00
# 7         อุตรดิตถ์       31086  ...            35405                     878.01
# 8             ระนอง       26522  ...            30948                     856.99
# 9          นราธิวาส       16968  ...            25709                     660.00
# 10            สงขลา       11462  ...            14382                     796.97
# ...

# %%
# t = list(df['province'])
# tmp = df.iloc[:, 0:2]
# tmp.plot(kind='bar', figsize=(15,5))
# plt.xticks(ticks=t)

# %%
sns.catplot(data=df, kind='bar', x='province', y='yield(ton)', aspect=3)
plt.xticks(rotation=90)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3633 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3607 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3610 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# **Thai language aren;t shown properly on seaborn plot. Need further improvement.**
