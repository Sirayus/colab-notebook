# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirayus/csv_file/blob/main/seaborn_library_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# ### Pre-loaded dataset : Tips

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Countplot

# %%
sns.countplot(x='sex', data=tips)

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue ='smoker')

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue ='smoker', hue_order=['No', 'Yes'])

# %%
hue_colors = {"Yes":"black", "No":"red"}
sns.scatterplot(x='total_bill', y='tip', data=tips, hue ='smoker', palette=hue_colors)

# %%
hue_colors = {"Yes":"#808080", "No":"#00FF00"}
sns.scatterplot(x='total_bill', y='tip', data=tips, hue ='smoker', palette=hue_colors)

# %% [markdown]
# ### Relplot
# lets you create subplots in a single figure

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col = 'smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', row = 'smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col = 'smoker', row='time')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col = 'day', col_wrap=2)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', size='size')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', size='size', hue='size')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', hue='smoker', style='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', alpha=0.4)

# %% [markdown]
# ### Line Plot

# %% [markdown]
# ### Catplot
# More flexibility like relplot. Could be use to plot multiple/ subplots.

# %% [markdown]
# Count plot

# %%
# sns.catplot( x='', data=df, kind='count', order=['value1', 'value2', 'value3'])

# %% [markdown]
# Bar plot is different. It shows 'mean' of the category instead of 'count' in count plot.

# %%
# sns.catplot( x='', y='', data=df, kind='bar')
# sns.catplot( x='', y='', data=df, kind='bar', ci=None)

# %% [markdown]
# Box Plot

# %%
# sns.catplot(x='', y='', kind='box')
# sns.catplot(x='', y='', kind='box', sym='') #stop showing outlier
# sns.catplot(x='', y='', kind='box', whis=1.5) # whis = 1.5/ 2.0/ [5, 95]/ [0, 100]

# %% [markdown]
# Point Plot

# %% [markdown]
# ### Customization

# %%
# sns.set_style('whitegrid')
# sns.set_style('ticks')
# sns.set_style('dark')
sns.set_style('darkgrid')
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter')

# %%
sns.set_style('white')
sns.set_palette('RdBu')
sns.countplot(x='sex', data=tips)

# %%
sns.reset_defaults
sns.set_palette('Blues')
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter')
